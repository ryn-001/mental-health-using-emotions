# %%
import pandas as pd

# %%
ID_COLUMN = "comment_id"
TEXT_COLUMN = "comment_text"

emotion_columns = [
    col for col in df.columns
    if col not in [ID_COLUMN, TEXT_COLUMN]
]

path = "https://ytcommentstorage.blob.core.windows.net/transformed-data/llm_cleaned.parquet?sv=2026-02-06&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2026-07-17T22:04:00Z&st=2026-06-17T13:49:00Z&spr=https&sig=kiL%2BVdjsVrc0PRmMNVAmLuG%2BpYEqTJpC%2BufjbP8dJU4%3D"
df = pd.read_parquet(path)

# %%
df.isnull().sum()
# Out:
# comment_id        0
# comment_text      0
# admiration        0
# amusement         0
# anger             0
# annoyance         0
# approval          0
# caring            0
# confusion         0
# curiosity         0
# desire            0
# disappointment    0
# disapproval       0
# disgust           0
# embarrassment     0
# excitement        0
# fear              0
# gratitude         0
# grief             0
# joy               0
# love              0
# nervousness       0
# optimism          0
# pride             0
# realization       0
# relief            0
# remorse           0
# sadness           0
# surprise          0
# neutral           0
# dtype: int64

# %% [markdown]
# Duplicate Ids

# %%
df[ID_COLUMN].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Duplicate Texts

# %%
df[TEXT_COLUMN].duplicated().sum()
# Out:
# np.int64(526)

# %% [markdown]
# Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Emotion Score Range

# %%
range_df = pd.DataFrame({
    "Minimum": df[emotion_columns].min(),
    "Maximum": df[emotion_columns].max()
})

range_df
# Out:
#                  Minimum   Maximum
# admiration      0.000111  0.992378
# amusement       0.000076  0.981320
# anger           0.000071  0.921957
# annoyance       0.000312  0.840389
# approval        0.000713  0.963863
# caring          0.000079  0.962861
# confusion       0.000082  0.964341
# curiosity       0.000088  0.948422
# desire          0.000131  0.944553
# disappointment  0.000126  0.912255
# disapproval     0.000101  0.950261
# disgust         0.000050  0.923143
# embarrassment   0.000025  0.934147
# excitement      0.000063  0.939412
# fear            0.000043  0.972613
# gratitude       0.000043  0.999153
# grief           0.000039  0.177594
# joy             0.000091  0.959959
# love            0.000103  0.987363
# nervousness     0.000032  0.884628
# optimism        0.000328  0.981080
# pride           0.000017  0.787714
# realization     0.000528  0.947845
# relief          0.000049  0.642280
# remorse         0.000032  0.858370
# sadness         0.000078  0.975394
# surprise        0.000037  0.971662
# neutral         0.000322  0.986970

# %%
invalid = {}

for col in emotion_columns:
    count = ((df[col] < 0) | (df[col] > 1)).sum()
    if count > 0:
        invalid[col] = count

if len(invalid) == 0:
    print("✓ All emotion scores are within the range [0, 1].")
else:
    print("Columns containing invalid values:")
    for col, count in invalid.items():
        print(f"{col}: {count}")
# Out:
# ✓ All emotion scores are within the range [0, 1].

# %%
non_numeric = []

for col in emotion_columns:
    if not pd.api.types.is_numeric_dtype(df[col]):
        non_numeric.append(col)

if len(non_numeric) == 0:
    print("✓ All emotion columns are numeric.")
else:
    print("Non-numeric emotion columns:")
    for col in non_numeric:
        print(col)
# Out:
# ✓ All emotion columns are numeric.
