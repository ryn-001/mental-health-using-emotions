# %%
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
SAS_TOKEN = os.getenv("SAS_TOKEN")

PATH = "https://ytcommentstorage.blob.core.windows.net/raw-extracted-data/academic_stress/1qq7lDL-bzY.parquet?" + SAS_TOKEN

# %%
df = pd.read_parquet(PATH)
df.head()
# Out:
#                    comment_id     video_id             author  \
# 0  Ugyehc_Tz3gPFErOrrd4AaABAg  1qq7lDL-bzY  @GranvilleEzparza
# 1  Ugy-QsLkEyAbYfmy1-h4AaABAg  1qq7lDL-bzY           @nuc2726
# 2  Ugz06JaA4Cd9YydQvFN4AaABAg  1qq7lDL-bzY         @almaisaks
# 3  Ugzp-erk3QqpwUnkhO14AaABAg  1qq7lDL-bzY    @KalmiaTheWitch
# 4  UgzvO1M4LXrmBILkvO54AaABAg  1qq7lDL-bzY     @nonebelow5110
#
#                                         comment_text  likes  \
# 0  Personally, this should be at least introduced...      0
# 1  the funniest part about how I was discovered t...      0
# 2  Why students should have mental health days | ...      0
# 3  I wish all schools take mental health more ser...      0
# 4                                          most late      0
#
#            published_at
# 0  2026-06-17T05:04:06Z
# 1  2026-05-10T14:13:46Z
# 2  2026-04-20T13:00:43Z
# 3  2026-04-11T19:59:20Z
# 4  2025-11-28T01:07:28Z
